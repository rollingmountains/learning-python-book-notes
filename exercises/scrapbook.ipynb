# %%
s = 'This is great'

lst = s.split(' ')

for index, word in enumerate(lst):
    if word == 'is':
        lst[index] = word.upper()

# %%
x = lambda lst: ' '.join([word.upper() if word == 'is' else word for word in lst])
x(['i', 'am', 'is'])

# %%
# sentences = [
#     "The sun rises in the east and sets in the west.",
#     "Python is a versatile programming language used for web development, data science, and automation.",
#     "Reading books can expand your knowledge and imagination."
# ]


# def keyword_highlight(lines, keyword):
#     result = []
#     for line in lines:
#         if keyword in line:
#             word_list = line.split(' ')
#             for index, word in enumerate(word_list):
#                 if word == keyword:
#                     word_list[index] = word.upper()
#             highlight_sentence = ' '.join(word_list)
#             result.append(highlight_sentence)

#     return (len(lines), len(result), result)


# total_sentences, matched_sentences, results = keyword_highlight(
#     sentences, keyword='and')
# print(
#     f'total_sentences = {total_sentences}\ntotal_matches = {matched_sentences}\nresult = {results}')


sentences = [
    "The sun rises in the east and sets in the west.",
    "Python is a versatile programming language used for web development, data science, and automation.",
    "Reading books can expand your knowledge and imagination."
]


def detect_match(text_list, keyword):
    match = [line for line in text_list if keyword in line]
    return match


def keyword_highlight(lines, keyword):
    matching_lines = detect_match(lines, keyword)
    result = []
    for line in matching_lines:
        word_list = line.split(' ')
        transform = lambda word_list : ' '.join(
            [word.upper() if word == keyword else word for word in word_list])
        result.append(transform(word_list))

    return result


r = keyword_highlight(sentences, keyword='east')
print(r)

# %%
def result(line, keyword):
    return keyword in line
result('this is lazy', 'bus')

# %%
def check(input): return input.isdigit()
r = list(filter(check, ['10','20','string']))
r

# %%
lst = [{'name': 'john'}, {'name': 'john'}, {'name': 'doe'}, {'name': 'doe'}]
sorted(lst, key=lambda x: x['name'])

# %%
all_actions = []
for record in lst:
    all_actions.append(record['name'])
unique_actions = set(all_actions)
unique_actions

# %%
d = {'Amit': 2, 'Sitaram': 3}
sorted(d, key=lambda x: d[x])
# Out:
# ['Amit', 'Sitaram']
