# %%
# in line comment is in file documentation 
# in line comment are good for small function or small group of code

# %%
# dir built in function is next in line
# it's all about the attributes of an object
# argument can be data type str, list etc or object name or object 
# literal

len(dir([])), len(dir(x for x in dir('') if not x.startswith('__')))
type({}), dir({}), len({1: 'one', 2: 'two', 3: 'three'})

d = {1: 'one', 2: 'two', 3: 'three'}
d.pop(1), d.popitem(), d
# Out:
# ('one', (3, 'three'), {2: 'two'})

# %%
def get_attr(obj):
    return [item for item in dir(obj) if not item.startswith('__')]
get_attr([])
get_attr({})
# Out:
# ['clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
# python built in docstring which can be followed in any code base
# Out:
# Set the maximum depth of the Python interpreter stack to n.
#
# This limit prevents infinite recursion from causing an overflow of the C
# stack and crashing Python.  The highest possible limit is platform-
# dependent.

# %%
{}.setdefault.__doc__
help({}.setdefault)
# Out:
# Help on built-in function setdefault:
#
# setdefault(key, default=None, /) method of builtins.dict instance
#     Insert key with a value of default if key is not in the dictionary.
#
#     Return the value for key if key is in the dictionary, else default.

# %%
d = {'name': 'john', 'age': 40}
d.setdefault('hobbie', 'sing') = 'dance'
d
# Out:
#   Cell In[2], line 2
#     d.setdefault('hobbie', 'sing') = 'dance'
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
d.
# Out:
#   Cell In[4], line 1
#     d.
#       ^
# SyntaxError: invalid syntax
